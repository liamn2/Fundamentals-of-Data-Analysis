# %%
#A clear and concise overview of the matplotlib.pyplot Python package [3],
#pitched at your classmates.

#25% An in-depth explanation of three interesting plots from the matplotlib.pyplot
#Python package [3]. You have free reign to choose the three plots yourself.

# %% [markdown]
# # matplotlib.pyplot Explained

# %% [markdown]
# matplotlib.pyplot is a library of functions used to simulate MATLAB software. The pyplot functions enable editabiltity of figures for users operating with the data visualisations of the matplotlib library. The user can use pyplot to format the style of their graphs and utilises plotting with keyword strings if needed. Graph lines can be set to an extensive list of attributes and categorical variables can be used to create plots. By categorical variables here, we mean variables that are selected from a set of pre-defined variable values.

# %% [markdown]
# We will examine 3 possible plots that can be created using the matplotlib.pyplot library. Namely, Pyplot Mathtext, Pyplot Simple and Pyplot Three respectively.
# ***

# %% [markdown]
# # Pyplot Mathtext Plot

# %%
import numpy as np
import matplotlib.pyplot as plt
t = np.arange(0.0, 2.0, 0.01)
s = np.sin(2*np.pi*t)

plt.plot(t, s)
plt.title(r'$\alpha_i > \beta_i$', fontsize=20)
plt.text(1, -0.6, r'$\sum_{i=0}^\infty x_i$', fontsize=20)
plt.text(0.6, 0.6, r'$\mathcal{A}\mathrm{sin}(2 \omega t)$',
         fontsize=20)
plt.xlabel('time (s)')
plt.ylabel('volts (mV)')
plt.show()

# %% [markdown]
# # References
#
# The preceding code was taken from the link below:
#
# https://matplotlib.org/stable/gallery/pyplots/pyplot_mathtext.html#sphx-glr-gallery-pyplots-pyplot-mathtext-py
#
# ***

# %% [markdown]
# # Pyplot Simple Plot

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()

# %% [markdown]
# # References

# %% [markdown]
# The preceding code was taken from the following link:
#
# https://matplotlib.org/stable/gallery/pyplots/pyplot_simple.html#sphx-glr-gallery-pyplots-pyplot-simple-py
#
# ***

# %% [markdown]
# # Pyplot Three Plot

# %%
import numpy as np
import matplotlib.pyplot as plt

# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %% [markdown]
# # References
# The preceding code was taken from the following link:
# https://matplotlib.org/stable/gallery/pyplots/pyplot_three.html#sphx-glr-gallery-pyplots-pyplot-three-py
#
# ***
